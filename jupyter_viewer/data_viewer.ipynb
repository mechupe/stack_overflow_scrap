# %% [markdown]
# ## List all available csv files
#
# ---

# %%
import os
from os import listdir
from os.path import isfile, join

def get_all_tags_filenames(folder_path = '../data/'):
    '''
    Get all csv file names
    '''
    os.chdir(folder_path)
    return [f for f in listdir(folder_path) if isfile(join(folder_path, f)) and f.endswith(".csv")]

# %%
get_all_tags_filenames()
# Out:
# ['uwp.csv',
#  'magento.csv',
#  'assembly.csv',
#  'jestjs.csv',
#  'hive.csv',
#  'flutter.csv',
#  'list.csv',
#  'mobile.csv',
#  'batch-file.csv',
#  'animation.csv',
#  'oracle11g.csv',
#  'rxjs.csv',
#  'wcf.csv',
#  'gwt.csv',
#  'lambda.csv',
#  'asp.net-mvc.csv',
#  'dependency-injection.csv',
#  'sqlite.csv',
#  'database.csv',
#  'scroll.csv',
#  'visual-studio-2012.csv',
#  'c#.csv',
#  'opengl.csv',
#  'visual-studio-2015.csv',
#  'version-control.csv',
#  'neo4j.csv',
#  'callback.csv',
#  'mongodb.csv',
#  'drupal.csv',
#  'dart.csv',
#  'uiviewcontroller.csv',
#  'types.csv',
#  'maven.csv',
#  'java.csv',
#  'ionic-framework.csv',
#  'cmd.csv',
#  'go.csv',
#  'reflection.csv',
#  'asp.net-mvc-5.csv',
#  'uitableview.csv',
#  'path.csv',
#  'datatable.csv',
#  'grails.csv',
#  'symfony.csv',
#  'django-rest-framework.csv',
#  'vector.csv',
#  'autocomplete.csv',
#  'redis.csv',
#  'ruby-on-rails.csv',
#  'deployment.csv',
#  'xaml.csv',
#  'merge.csv',
#  'mod-rewrite.csv',
#  'spring-security.csv',
#  'math.csv',
#  'svn.csv',
#  'ruby-on-rails-4.csv',
#  'image-processing.csv',
#  'binding.csv',
#  'beautifulsoup.csv',
#  'android-studio.csv',
#  'internet-explorer.csv',
#  'routes.csv',
#  'encryption.csv',
#  'bluetooth.csv',
#  'spring-mvc.csv',
#  'powershell.csv',
#  'lua.csv',
#  'matrix.csv',
#  'xamarin.csv',
#  'sqlalchemy.csv',
#  'nullpointerexception.csv',
#  'mysqli.csv',
#  'iframe.csv',
#  'bash.csv',
#  'express.csv',
#  'scope.csv',
#  'highcharts.csv',
#  'logging.csv',
#  'winforms.csv',
#  'server.csv',
#  'c++11.csv',
#  'twitter-bootstrap-3.csv',
#  'pdo.csv',
#  'plugins.csv',
#  'vbscript.csv',
#  'web-services.csv',
#  'ecmascript-6.csv',
#  'visual-c++.csv',
#  'ms-word.csv',
#  'asp.net-mvc-3.csv',
#  'ffmpeg.csv',
#  'forms.csv',
#  'cmake.csv',
#  'post.csv',
#  'ember.js.csv',
#  'parallel-processing.csv',
#  'machine-learning.csv',
#  'struct.csv',
#  'csv.csv',
#  'razor.csv',
#  'spring.csv',
#  'process.csv',
#  'kendo-ui.csv',
#  'view.csv',
#  'sorting.csv',
#  'url.csv',
#  'heroku.csv',
#  'keras.csv',
#  'flash.csv',
#  'jmeter.csv',
#  'object.csv',
#  'get.csv',
#  'time.csv',
#  'rest.csv',
#  'dom.csv',
#  'svg.csv',
#  'doctrine-orm.csv',
#  'awk.csv',
#  'drop-down-menu.csv',
#  'aws-lambda.csv',
#  'cordova.csv',
#  'arduino.csv',
#  'meteor.csv',
#  'android-fragments.csv',
#  'fonts.csv',
#  'google-api.csv',
#  'sql-server-2008.csv',
#  'stored-procedures.csv',
#  'xamarin.android.csv',
#  'html.csv',
#  'azure-devops.csv',
#  'io.csv',
#  'intellij-idea.csv',
#  'urllib.csv',
#  'kotlin.csv',
#  'laravel.csv',
#  'optimization.csv',
#  'visual-studio-2008.csv',
#  'serialization.csv',
#  'google-bigquery.csv',
#  'nlp.csv',
#  'button.csv',
#  'linked-list.csv',
#  'cocoa-touch.csv',
#  'opencv.csv',
#  'error-handling.csv',
#  'raspberry-pi.csv',
#  'ios.csv',
#  'html-table.csv',
#  'apache-kafka.csv',
#  'firefox.csv',
#  'directory.csv',
#  'android.csv',
#  'c#-4.0.csv',
#  'algorithm.csv',
#  'enums.csv',
#  'lxml.csv',
#  'promise.csv',
#  'unix.csv',
#  'templates.csv',
#  'printing.csv',
#  'delphi.csv',
#  'scikit-learn.csv',
#  'string.csv',
#  'ssis.csv',
#  'webview.csv',
#  'facebook.csv',
#  'linq.csv',
#  'sql.csv',
#  'react-native.csv',
#  'web-applications.csv',
#  'utf-8.csv',
#  'makefile.csv',
#  'file.csv',
#  'tcp.csv',
#  'socket.io.csv',
#  'react-redux.csv',
#  'plot.csv',
#  'safari.csv',
#  'matlab.csv',
#  'excel-formula.csv',
#  'google-maps-api-3.csv',
#  'sockets.csv',
#  'text.csv',
#  'laravel-5.csv',
#  'django-templates.csv',
#  'multithreading.csv',
#  'random.csv',
#  'dictionary.csv',
#  'axios.csv',
#  'https.csv',
#  'matplotlib.csv',
#  'reporting-services.csv',
#  'c.csv',
#  'curl.csv',
#  'windows-phone-8.csv',
#  'pip.csv',
#  'rust.csv',
#  'gridview.csv',
#  'google-cloud-firestore.csv',
#  'design-patterns.csv',
#  'url-rewriting.csv',
#  'tkinter.csv',
#  'events.csv',
#  'visual-studio-2013.csv',
#  'group-by.csv',
#  'mongoose.csv',
#  'performance.csv',
#  'http.csv',
#  'validation.csv',
#  'entity-framework-core.csv',
#  'login.csv',
#  'spring-data-jpa.csv',
#  'php.csv',
#  'unit-testing.csv',
#  'websocket.csv',
#  'import.csv',
#  'react-router.csv',
#  'dplyr.csv',
#  'memory.csv',
#  'macos.csv',
#  'scripting.csv',
#  'video.csv',
#  'installation.csv',
#  'sql-server-2005.csv',
#  'oauth-2.0.csv',
#  'listview.csv',
#  'inheritance.csv',
#  'jquery-mobile.csv',
#  'jupyter-notebook.csv',
#  'orm.csv',
#  'filter.csv',
#  'jenkins.csv',
#  'google-cloud-platform.csv',
#  'datagridview.csv',
#  'playframework.csv',
#  'cron.csv',
#  'properties.csv',
#  'python-requests.csv',
#  'loops.csv',
#  'tsql.csv',
#  'indexing.csv',
#  'datagrid.csv',
#  'android-activity.csv',
#  'recursion.csv',
#  'mvvm.csv',
#  'jsf.csv',
#  'select.csv',
#  'function.csv',
#  'shell.csv',
#  'postgresql.csv',
#  'python-2.7.csv',
#  'exception.csv',
#  '3d.csv',
#  'graph.csv',
#  'database-design.csv',
#  'typescript.csv',
#  'visual-studio-2010.csv',
#  'python.csv',
#  'javascript.csv',
#  'zend-framework.csv',
#  'nginx.csv',
#  'vue.js.csv',
#  'dns.csv',
#  'foreach.csv',
#  'yii.csv',
#  'pointers.csv',
#  'browser.csv',
#  'vb.net.csv',
#  'oop.csv',
#  'react-hooks.csv',
#  'generics.csv',
#  'tensorflow.csv',
#  'qt.csv',
#  'docker.csv',
#  'apache-spark-sql.csv',
#  'debugging.csv',
#  'collections.csv',
#  'angularjs-directive.csv',
#  'push-notification.csv',
#  'angular-material.csv',
#  'model.csv',
#  'scrapy.csv',
#  'winapi.csv',
#  'asp.net-web-api.csv',
#  'rspec.csv',
#  'module.csv',
#  'search.csv',
#  'memory-management.csv',
#  'entity-framework.csv',
#  'count.csv',
#  'datatables.csv',
#  'codeigniter.csv',
#  'neural-network.csv',
#  'proxy.csv',
#  'jquery-ui.csv',
#  'join.csv',
#  'hyperlink.csv',
#  'urllib2.csv',
#  'c++.csv',
#  'perl.csv',
#  'primefaces.csv',
#  'datepicker.csv',
#  'api.csv',
#  'apache.csv',
#  'memory-leaks.csv',
#  'facebook-graph-api.csv',
#  'apache-flex.csv',
#  'architecture.csv',
#  'node.js.csv',
#  'arrays.csv',
#  'jpa.csv',
#  'ubuntu.csv',
#  'xamarin.ios.csv',
#  'cookies.csv',
#  'amazon-s3.csv',
#  'jsp.csv',
#  'django-models.csv',
#  'variables.csv',
#  'xslt.csv',
#  'github.csv',
#  'solr.csv',
#  'responsive-design.csv',
#  'visual-studio-code.csv',
#  'compiler-errors.csv',
#  'constructor.csv',
#  'tree.csv',
#  'cocoa.csv',
#  'silverlight.csv',
#  'ssl.csv',
#  'flexbox.csv',
#  'numpy.csv',
#  'tomcat.csv',
#  'css.csv',
#  'jsf-2.csv',
#  'canvas.csv',
#  'windows.csv',
#  'd3.js.csv',
#  'methods.csv',
#  'ansible.csv',
#  'oauth.csv',
#  'parsing.csv',
#  'servlets.csv',
#  'bitmap.csv',
#  'reactjs.csv',
#  'sass.csv',
#  'casting.csv',
#  'azure.csv',
#  'elasticsearch.csv',
#  'hadoop.csv',
#  'static.csv',
#  'concurrency.csv',
#  'npm.csv',
#  'asynchronous.csv',
#  'amazon-ec2.csv',
#  'interface.csv',
#  'android-listview.csv',
#  'input.csv',
#  'permissions.csv',
#  'functional-programming.csv',
#  'vim.csv',
#  'android-recyclerview.csv',
#  'extjs.csv',
#  'datetime.csv',
#  'visual-studio.csv',
#  'phpmyadmin.csv',
#  'download.csv',
#  'ggplot2.csv',
#  'sql-server-2012.csv',
#  'while-loop.csv',
#  'pygame.csv',
#  'arraylist.csv',
#  'wpf.csv',
#  'iis.csv',
#  'service.csv',
#  'pdf.csv',
#  'request.csv',
#  'shiny.csv',
#  'pyspark.csv',
#  'r.csv',
#  'xcode.csv',
#  'model-view-controller.csv',
#  'class.csv',
#  'windows-phone-7.csv',
#  'automation.csv',
#  'parameters.csv',
#  'android-layout.csv',
#  'swift3.csv',
#  'reference.csv',
#  'linux-kernel.csv',
#  'eclipse.csv',
#  'for-loop.csv',
#  'web.csv',
#  'ruby-on-rails-3.csv',
#  'hibernate.csv',
#  'paypal.csv',
#  'build.csv',
#  'multidimensional-array.csv',
#  'deep-learning.csv',
#  'caching.csv',
#  'gradle.csv',
#  'unicode.csv',
#  'layout.csv',
#  'sharepoint.csv',
#  'junit.csv',
#  'asp.net-core.csv',
#  'asp.net-mvc-4.csv',
#  'spring-boot.csv',
#  'boost.csv',
#  'terminal.csv',
#  'flask.csv',
#  'email.csv',
#  'powerquery.csv',
#  'mechanicalsoup.csv',
#  'nhibernate.csv',
#  'xpath.csv',
#  'java-8.csv',
#  'google-sheets.csv',
#  'swing.csv',
#  'redirect.csv',
#  'command-line.csv',
#  'dll.csv',
#  'ssh.csv',
#  'authentication.csv',
#  'google-apps-script.csv',
#  'google-maps.csv',
#  'woocommerce.csv',
#  'google-app-engine.csv',
#  'vuejs2.csv',
#  'selenium-webdriver.csv',
#  'testing.csv',
#  'controller.csv',
#  'jakarta-ee.csv',
#  'web-scraping.csv',
#  'google-chrome.csv',
#  'javafx.csv',
#  'parse-platform.csv',
#  'jdbc.csv',
#  'triggers.csv',
#  'xml.csv',
#  'plsql.csv',
#  'vba.csv',
#  'syntax.csv',
#  'gcc.csv',
#  'ms-access.csv',
#  'git.csv',
#  'emacs.csv',
#  'dynamic.csv',
#  'android-intent.csv',
#  'docker-compose.csv',
#  'eloquent.csv',
#  'split.csv',
#  'session.csv',
#  'apache-spark.csv',
#  'scala.csv',
#  'webpack.csv',
#  'f#.csv',
#  'oracle.csv',
#  'outlook.csv',
#  'django-views.csv',
#  'security.csv',
#  'tfs.csv',
#  'jquery.csv',
#  'file-upload.csv',
#  'graphql.csv',
#  'graphics.csv',
#  'jar.csv',
#  'dataframe.csv',
#  'activerecord.csv',
#  'redux.csv',
#  'pyqt.csv',
#  'django-forms.csv',
#  'amazon-web-services.csv',
#  'colors.csv',
#  'scipy.csv',
#  'firebase-realtime-database.csv',
#  'mysql.csv',
#  'google-chrome-extension.csv',
#  'user-interface.csv',
#  'clojure.csv',
#  'twitter.csv',
#  'xamarin.forms.csv',
#  'checkbox.csv',
#  'data-binding.csv',
#  'sed.csv',
#  'encoding.csv',
#  'asp.net.csv',
#  'selenium.csv',
#  'google-analytics.csv',
#  'uiview.csv',
#  'three.js.csv',
#  'haskell.csv',
#  'netbeans.csv',
#  'networking.csv',
#  'actionscript-3.csv',
#  'configuration.csv',
#  'twitter-bootstrap.csv',
#  'firebase-authentication.csv',
#  'wordpress.csv',
#  'file-io.csv',
#  'firebase.csv',
#  'swiftui.csv',
#  'date.csv',
#  'groovy.csv',
#  'cassandra.csv',
#  'unity3d.csv',
#  'kubernetes.csv',
#  'audio.csv',
#  'compilation.csv',
#  'knockout.js.csv',
#  'charts.csv',
#  'replace.csv',
#  'pagination.csv',
#  'bootstrap-4.csv',
#  'core-data.csv',
#  'combobox.csv',
#  'backbone.js.csv',
#  'data-structures.csv',
#  'async-await.csv',
#  'timer.csv',
#  'cakephp.csv',
#  'if-statement.csv',
#  'hash.csv',
#  'ipad.csv',
#  'image.csv',
#  'soap.csv']

# %% [markdown]
# ## Read a csv file as data frame
#
# ---

# %%
import pandas as pd
import datetime as dt

def get_tag_df(file_name, folder_path = '../data/'):
    tag_data = pd.read_csv(join(folder_path, file_name), sep=':')
    # Drop redundant index column
    tag_data.dropna(subset = ["Unnamed: 0"], inplace=True)
    tag_data.drop(columns=['Unnamed: 0'], inplace=True)
    # Update index
    tag_data.reset_index(drop=True, inplace=True)
    # Set data types
    tag_data['date'] = pd.to_datetime(tag_data['date'])
    tag_data['id'] = tag_data['id'].astype(int)
    tag_data['vote'] = tag_data['vote'].astype(int)
    tag_data['answer'] = tag_data['answer'].astype(int)
    tag_data['views'] = tag_data['views'].astype(int)
    tag_data['accepted'] = tag_data['accepted'].apply(lambda value: bool(value == 'True')).astype(bool)
    return tag_data

# %%
get_tag_df('cakephp.csv')
# Out:
#           tag        id  vote  answer  views  accepted       date
# 0     cakephp  69649623     0       1     12     False 2021-10-20
# 1     cakephp  69637611     0       0     28     False 2021-10-19
# 2     cakephp  69633927     0       0     42     False 2021-10-19
# 3     cakephp  69633433     0       0     20     False 2021-10-19
# 4     cakephp  69628876     0       1     29     False 2021-10-19
# ...       ...       ...   ...     ...    ...       ...        ...
# 4995  cakephp  40028327     0       2    589     False 2016-10-13
# 4996  cakephp  40026574     0       1    384      True 2016-10-13
# 4997  cakephp  40026349     0       0     56     False 2016-10-13
# 4998  cakephp  40023269     0       1     46     False 2016-10-13
# 4999  cakephp  40017581     0       2    231      True 2016-10-13
#
# [5000 rows x 7 columns]

# %% [markdown]
# ## Example of joining several tables
#
# ---

# %%
beautifulsoup = get_tag_df('beautifulsoup.csv')
lxml = get_tag_df('lxml.csv')
selenium = get_tag_df('selenium.csv')
scrapy = get_tag_df('scrapy.csv')
mechanicalsoup = get_tag_df('mechanicalsoup.csv')
urllib = get_tag_df('urllib.csv')
urllib2 = get_tag_df('urllib2.csv')

scrapy_libs = [beautifulsoup, lxml, selenium, scrapy, mechanicalsoup, urllib, urllib2]

# %%
scrapy_df = pd.concat(scrapy_libs)

# %%
scrapy_df
# Out:
#                 tag        id  vote  answer  views  accepted       date
# 0     beautifulsoup  69651927     0       1     14     False 2021-10-20
# 1     beautifulsoup  69651870     0       0      9     False 2021-10-20
# 2     beautifulsoup  69648558     0       0     14     False 2021-10-20
# 3     beautifulsoup  69646624     0       2     43     False 2021-10-20
# 4     beautifulsoup  69646378    -1       0     24     False 2021-10-20
# ...             ...       ...   ...     ...    ...       ...        ...
# 2803        urllib2    163603     6       2   6000      True 2008-10-02
# 2804        urllib2    163009    31      14  40000      True 2008-10-02
# 2805        urllib2    151929     6       3   6000      True 2008-09-30
# 2806        urllib2    148853    13       7   9000      True 2008-09-29
# 2807        urllib2    120061    40      10  27000      True 2008-09-23
#
# [26467 rows x 7 columns]

# %%
# Form pivot table to see which tags of interest are assigned to every question 

questions_df = scrapy_df.pivot_table(
    values='views',
    index=['id'],
    columns='tag',
    aggfunc='median',
    fill_value=0
)

# %%
questions_df[questions_df.apply(lambda x: x['beautifulsoup'] > 0 and x['beautifulsoup'] < sum(x[:]), axis=1)]
# Out:
# tag       beautifulsoup  lxml  mechanicalsoup  scrapy  selenium  urllib  \
# id
# 64049423             50    50               0       0         0       0
# 64066003            129   129               0       0         0       0
# 64085429             91     0               0      91         0       0
# 64173263             47    47               0       0         0       0
# 64200882            139   140               0       0         0       0
# ...                 ...   ...             ...     ...       ...     ...
# 69600452             32     0               0       0        33       0
# 69617685             57     0               0       0         0      57
# 69632674             16     0               0       0        17       0
# 69633732             26     0               0       0        26       0
# 69635360             18     0               0       0        18       0
#
# tag       urllib2
# id
# 64049423        0
# 64066003        0
# 64085429        0
# 64173263        0
# 64200882        0
# ...           ...
# 69600452        0
# 69617685        0
# 69632674        0
# 69633732        0
# 69635360        0
#
# [322 rows x 7 columns]
